# %% [markdown]
# <a href="https://colab.research.google.com/github/p65454/ds-section1-sprint1-new/blob/main/n111a_EDA(1)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 1*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# # 1. 데이터셋 불러오기 및 확인
#
# - 다음 url에서 엑셀 파일을 불러오세요. (pandas excel)
#   - https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx
#   - 파일은 2개의 시트로 구성되어 있으며 각각 이름은 008770, 035250 입니다.
#
# - 데이터셋 변수의 이름은 df1, df2로 저장하세요.
#
# - row가 아닌 column에 '매출액', '영업이익' 이 가도록 데이터를 transpose 하세요.
#
# - 이후 아래 링크를 참조하여 첫번째 row를 column name으로 설정하세요. <br>
#   https://stackoverflow.com/questions/31328861/python-pandas-replacing-header-with-top-row
#
# - 데이터의 dimension을 확인하세요.
#
# - 데이터의 결측치가 어디에 있는지 확인 후 0으로 대체하세요.
#
# - 읽었던 엑셀 파일의 내용을 2개의 csv로 각각 출력하세요. (python export csv)
#   - 이름은 각각 df1.csv, df2.csv 입니다.

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-283df4dc-ea6e-4820-b87a-b0d64b760e66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-283df4dc-ea6e-4820-b87a-b0d64b760e66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Travel.xlsx to Travel.xlsx

# %%
df1 = pd.read_excel('Travel.xlsx', sheet_name = 0)
df2 = pd.read_excel('Travel.xlsx', sheet_name = 1)
df1.head()
# Out:
#        주요재무정보  2019/09\n(IFRS연결)  2019/12\n(IFRS연결)  2020/03\n(IFRS연결)  \
# 0         매출액            14753.0            15440.0             9437.0
# 1        영업이익              574.0              776.0             -668.0
# 2  영업이익(발표기준)              574.0              776.0             -668.0
# 3    세전계속사업이익              376.0              538.0             -925.0
# 4       당기순이익              274.0              380.0             -736.0
#
#    2020/06\n(IFRS연결)  2020/09\n(IFRS연결)  2020/12(E)\n(IFRS연결)  \
# 0             5230.0             8795.0                9980.0
# 1             -634.0             -198.0                  50.0
# 2             -634.0             -198.0                   NaN
# 3             -819.0             -366.0                -109.0
# 4             -677.0             -285.0                -100.0
#
#    2021/03(E)\n(IFRS연결)  2021/06(E)\n(IFRS연결)
# 0                9761.0                9820.0
# 1                 144.0                 265.0
# 2                   NaN                   NaN
# 3                  14.0                 172.0
# 4                  71.0                 214.0

# %%
df2.head()
# Out:
#        주요재무정보  2019/09\n(IFRS연결)  2019/12\n(IFRS연결)  2020/03\n(IFRS연결)  \
# 0         매출액             4055.0             3728.0             2360.0
# 1        영업이익             1392.0              641.0            -1868.0
# 2  영업이익(발표기준)             1392.0              641.0            -1868.0
# 3    세전계속사업이익             1554.0              769.0            -2204.0
# 4       당기순이익             1286.0              526.0            -1561.0
#
#    2020/06\n(IFRS연결)  2020/09\n(IFRS연결)  2020/12(E)\n(IFRS연결)  \
# 0              346.0              766.0                1581.0
# 1            -1038.0             -649.0                -434.0
# 2            -1038.0             -649.0                   NaN
# 3             -723.0             -552.0                -331.0
# 4             -456.0             -409.0                -465.0
#
#    2021/03(E)\n(IFRS연결)  2021/06(E)\n(IFRS연결)
# 0                1473.0                1746.0
# 1                -187.0                 -65.0
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN

# %%
df1 = df1.transpose()
df2 = df2.transpose()

# %%
df1.head()
# Out:
#                         0      1           2         3      4          5   \
# 주요재무정보                 매출액   영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)
# 2019/09\n(IFRS연결)  14753.0  574.0       574.0     376.0  274.0      277.0
# 2019/12\n(IFRS연결)  15440.0  776.0       776.0     538.0  380.0      380.0
# 2020/03\n(IFRS연결)   9437.0 -668.0      -668.0    -925.0 -736.0     -736.0
# 2020/06\n(IFRS연결)   5230.0 -634.0      -634.0    -819.0 -677.0     -678.0
#
#                            6        7        8       9   ...      22      23  \
# 주요재무정보             당기순이익(비지배)     자산총계     부채총계    자본총계  ...  ROA(%)    부채비율
# 2019/09\n(IFRS연결)        -3.0  37747.0  28854.0  8893.0  ...    3.62  324.45
# 2019/12\n(IFRS연결)         0.0  35273.0  26077.0  9195.0  ...    5.81  283.59
# 2020/03\n(IFRS연결)         0.0  33188.0  24813.0  8375.0  ...    1.25  296.28
# 2020/06\n(IFRS연결)         1.0  33039.0  25364.0  7676.0  ...   -2.14  330.45
#
#                        24      25      26       27      28        29       30  \
# 주요재무정보              자본유보율  EPS(원)  PER(배)   BPS(원)  PBR(배)  현금DPS(원)  현금배당수익률
# 2019/09\n(IFRS연결)   395.1   692.0   31.19  23484.0    3.67       0.0      NaN
# 2019/12\n(IFRS연결)  411.78   950.0    21.4  24282.0    3.74     350.0      NaN
# 2020/03\n(IFRS연결)  368.36 -1839.0   63.76  22114.0    3.19       NaN      NaN
# 2020/06\n(IFRS연결)  334.46 -1695.0     NaN  20265.0     3.5       NaN      NaN
#
#                           31
# 주요재무정보             현금배당성향(%)
# 2019/09\n(IFRS연결)        0.0
# 2019/12\n(IFRS연결)      34.94
# 2020/03\n(IFRS연결)        0.0
# 2020/06\n(IFRS연결)        0.0
#
# [5 rows x 32 columns]

# %%
new_header = df1.iloc[0]
df1 = df1[1:]
df1.columns = new_header
df1.head()
# Out:
# 주요재무정보                 매출액   영업이익 영업이익(발표기준) 세전계속사업이익  당기순이익 당기순이익(지배)  \
# 2019/09\n(IFRS연결)  14753.0  574.0      574.0    376.0  274.0     277.0
# 2019/12\n(IFRS연결)  15440.0  776.0      776.0    538.0  380.0     380.0
# 2020/03\n(IFRS연결)   9437.0 -668.0     -668.0   -925.0 -736.0    -736.0
# 2020/06\n(IFRS연결)   5230.0 -634.0     -634.0   -819.0 -677.0    -678.0
# 2020/09\n(IFRS연결)   8795.0 -198.0     -198.0   -366.0 -285.0    -285.0
#
# 주요재무정보            당기순이익(비지배)     자산총계     부채총계    자본총계  ... ROA(%)    부채비율  \
# 2019/09\n(IFRS연결)       -3.0  37747.0  28854.0  8893.0  ...   3.62  324.45
# 2019/12\n(IFRS연결)        0.0  35273.0  26077.0  9195.0  ...   5.81  283.59
# 2020/03\n(IFRS연결)        0.0  33188.0  24813.0  8375.0  ...   1.25  296.28
# 2020/06\n(IFRS연결)        1.0  33039.0  25364.0  7676.0  ...  -2.14  330.45
# 2020/09\n(IFRS연결)        0.0  32683.0  25318.0  7365.0  ...  -3.74  343.77
#
# 주요재무정보              자본유보율  EPS(원) PER(배)   BPS(원) PBR(배) 현금DPS(원) 현금배당수익률  \
# 2019/09\n(IFRS연결)   395.1   692.0  31.19  23484.0   3.67      0.0     NaN
# 2019/12\n(IFRS연결)  411.78   950.0   21.4  24282.0   3.74    350.0     NaN
# 2020/03\n(IFRS연결)  368.36 -1839.0  63.76  22114.0   3.19      NaN     NaN
# 2020/06\n(IFRS연결)  334.46 -1695.0    NaN  20265.0    3.5      NaN     NaN
# 2020/09\n(IFRS연결)  320.21  -712.0    NaN  19444.0   3.91      NaN     NaN
#
# 주요재무정보            현금배당성향(%)
# 2019/09\n(IFRS연결)       0.0
# 2019/12\n(IFRS연결)     34.94
# 2020/03\n(IFRS연결)       0.0
# 2020/06\n(IFRS연결)       0.0
# 2020/09\n(IFRS연결)       NaN
#
# [5 rows x 32 columns]

# %%
new_header = df2.iloc[0]
df2 = df2[1:]
df2.columns = new_header
df2.head()
# Out:
# 주요재무정보                매출액    영업이익 영업이익(발표기준) 세전계속사업이익   당기순이익 당기순이익(지배)  \
# 2019/09\n(IFRS연결)  4055.0  1392.0     1392.0   1554.0  1286.0    1286.0
# 2019/12\n(IFRS연결)  3728.0   641.0      641.0    769.0   526.0     526.0
# 2020/03\n(IFRS연결)  2360.0 -1868.0    -1868.0  -2204.0 -1561.0   -1561.0
# 2020/06\n(IFRS연결)   346.0 -1038.0    -1038.0   -723.0  -456.0    -456.0
# 2020/09\n(IFRS연결)   766.0  -649.0     -649.0   -552.0  -409.0    -409.0
#
# 주요재무정보            당기순이익(비지배)     자산총계    부채총계     자본총계  ... ROA(%)   부채비율  \
# 2019/09\n(IFRS연결)        0.0  41698.0  4781.0  36917.0  ...    7.2  12.95
# 2019/12\n(IFRS연결)        0.0  44381.0  7204.0  37178.0  ...   7.72  19.38
# 2020/03\n(IFRS연결)        0.0  43702.0  9945.0  33757.0  ...   1.75  29.46
# 2020/06\n(IFRS연결)        0.0  39178.0  5900.0  33277.0  ...   -0.5  17.73
# 2020/09\n(IFRS연결)        0.0  37434.0  4560.0  32875.0  ...   -4.8  13.87
#
# 주요재무정보               자본유보율 EPS(원) PER(배)   BPS(원) PBR(배) 현금DPS(원) 현금배당수익률  \
# 2019/09\n(IFRS연결)  3513.86  601.0   21.0  18209.0   1.62      0.0     NaN
# 2019/12\n(IFRS연결)  3538.24  246.0  18.92  18337.0   1.61    900.0     NaN
# 2020/03\n(IFRS연결)  3218.48 -730.0  55.53  16650.0   1.19      NaN     NaN
# 2020/06\n(IFRS연결)  3173.64 -213.0    NaN  16414.0   1.31      NaN     NaN
# 2020/09\n(IFRS연결)   3136.0 -191.0    NaN  16215.0   1.33      NaN     NaN
#
# 주요재무정보            현금배당성향(%)
# 2019/09\n(IFRS연결)       0.0
# 2019/12\n(IFRS연결)    346.75
# 2020/03\n(IFRS연결)       NaN
# 2020/06\n(IFRS연결)       0.0
# 2020/09\n(IFRS연결)       NaN
#
# [5 rows x 32 columns]

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (8, 32)
# (8, 32)

# %%
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 2019/09
# (IFRS연결) to 2021/06(E)
# (IFRS연결)
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   매출액         8 non-null      object
#  1   영업이익        8 non-null      object
#  2   영업이익(발표기준)  5 non-null      object
#  3   세전계속사업이익    8 non-null      object
#  4   당기순이익       8 non-null      object
#  5   당기순이익(지배)   8 non-null      object
#  6   당기순이익(비지배)  5 non-null      object
#  7   자산총계        6 non-null      object
#  8   부채총계        6 non-null      object
#  9   자본총계        6 non-null      object
#  10  자본총계(지배)    6 non-null      object
#  11  자본총계(비지배)   5 non-null      object
#  12  자본금         6 non-null      object
#  13  영업활동현금흐름    5 non-null      object
#  14  투자활동현금흐름    5 non-null      object
#  15  재무활동현금흐름    5 non-null      object
#  16  CAPEX       5 non-null      object
#  17  FCF         5 non-null      object
#  18  이자발생부채      5 non-null      object
#  19  영업이익률       8 non-null      object
#  20  순이익률        8 non-null      object
#  21  ROE(%)      5 non-null      object
#  22  ROA(%)      5 non-null      object
#  23  부채비율        6 non-null      object
#  24  자본유보율       5 non-null      object
#  25  EPS(원)      8 non-null      object
#  26  PER(배)      3 non-null      object
#  27  BPS(원)      6 non-null      object
#  28  PBR(배)      6 non-null      object
#  29  현금DPS(원)    2 non-null      object
#  30  현금배당수익률     0 non-null      object
#  31  현금배당성향(%)   4 non-null      object
# dtypes: object(32)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 2019/09
# (IFRS연결) to 2021/06(E)
# (IFRS연결)
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   매출액         8 non-null      object
#  1   영업이익        8 non-null      object
#  2   영업이익(발표기준)  5 non-null      object
#  3   세전계속사업이익    6 non-null      object
#  4   당기순이익       6 non-null      object
#  5   당기순이익(지배)   8 non-null      object
#  6   당기순이익(비지배)  5 non-null      object
#  7   자산총계        6 non-null      object
#  8   부채총계        6 non-null      object
#  9   자본총계        6 non-null      object
#  10  자본총계(지배)    6 non-null      object
#  11  자본총계(비지배)   2 non-null      object
#  12  자본금         6 non-null      object
#  13  영업활동현금흐름    5 non-null      object
#  14  투자활동현금흐름    5 non-null      object
#  15  재무활동현금흐름    5 non-null      object
#  16  CAPEX       5 non-null      object
#  17  FCF         5 non-null      object
#  18  이자발생부채      5 non-null      object
#  19  영업이익률       8 non-null      object
#  20  순이익률        6 non-null      object
#  21  ROE(%)      5 non-null      object
#  22  ROA(%)      5 non-null      object
#  23  부채비율        6 non-null      object
#  24  자본유보율       5 non-null      object
#  25  EPS(원)      8 non-null      object
#  26  PER(배)      3 non-null      object
#  27  BPS(원)      6 non-null      object
#  28  PBR(배)      6 non-null      object
#  29  현금DPS(원)    2 non-null      object
#  30  현금배당수익률     0 non-null      object
#  31  현금배당성향(%)   3 non-null      object
# dtypes: object(32)
# memory usage: 2.1+ KB

# %%
df1.isnull()
df2.isnull()
# Out:
# 주요재무정보                  매출액   영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)  \
# 2019/09\n(IFRS연결)     False  False       False     False  False      False
# 2019/12\n(IFRS연결)     False  False       False     False  False      False
# 2020/03\n(IFRS연결)     False  False       False     False  False      False
# 2020/06\n(IFRS연결)     False  False       False     False  False      False
# 2020/09\n(IFRS연결)     False  False       False     False  False      False
# 2020/12(E)\n(IFRS연결)  False  False        True     False  False      False
# 2021/03(E)\n(IFRS연결)  False  False        True      True   True      False
# 2021/06(E)\n(IFRS연결)  False  False        True      True   True      False
#
# 주요재무정보                당기순이익(비지배)   자산총계   부채총계   자본총계  ...  ROA(%)   부채비율  \
# 2019/09\n(IFRS연결)          False  False  False  False  ...   False  False
# 2019/12\n(IFRS연결)          False  False  False  False  ...   False  False
# 2020/03\n(IFRS연결)          False  False  False  False  ...   False  False
# 2020/06\n(IFRS연결)          False  False  False  False  ...   False  False
# 2020/09\n(IFRS연결)          False  False  False  False  ...   False  False
# 2020/12(E)\n(IFRS연결)        True  False  False  False  ...    True  False
# 2021/03(E)\n(IFRS연결)        True   True   True   True  ...    True   True
# 2021/06(E)\n(IFRS연결)        True   True   True   True  ...    True   True
#
# 주요재무정보                자본유보율  EPS(원)  PER(배)  BPS(원)  PBR(배)  현금DPS(원)  \
# 2019/09\n(IFRS연결)     False   False   False   False   False     False
# 2019/12\n(IFRS연결)     False   False   False   False   False     False
# 2020/03\n(IFRS연결)     False   False   False   False   False      True
# 2020/06\n(IFRS연결)     False   False    True   False   False      True
# 2020/09\n(IFRS연결)     False   False    True   False   False      True
# 2020/12(E)\n(IFRS연결)   True   False    True   False   False      True
# 2021/03(E)\n(IFRS연결)   True   False    True    True    True      True
# 2021/06(E)\n(IFRS연결)   True   False    True    True    True      True
#
# 주요재무정보                현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)        True      False
# 2019/12\n(IFRS연결)        True      False
# 2020/03\n(IFRS연결)        True       True
# 2020/06\n(IFRS연결)        True      False
# 2020/09\n(IFRS연결)        True       True
# 2020/12(E)\n(IFRS연결)     True       True
# 2021/03(E)\n(IFRS연결)     True       True
# 2021/06(E)\n(IFRS연결)     True       True
#
# [8 rows x 32 columns]

# %%
df1.fillna(0)
df2.fillna(0)
# Out:
# 주요재무정보                   매출액    영업이익  영업이익(발표기준)  세전계속사업이익   당기순이익  당기순이익(지배)  \
# 2019/09\n(IFRS연결)     4055.0  1392.0      1392.0    1554.0  1286.0     1286.0
# 2019/12\n(IFRS연결)     3728.0   641.0       641.0     769.0   526.0      526.0
# 2020/03\n(IFRS연결)     2360.0 -1868.0     -1868.0   -2204.0 -1561.0    -1561.0
# 2020/06\n(IFRS연결)      346.0 -1038.0     -1038.0    -723.0  -456.0     -456.0
# 2020/09\n(IFRS연결)      766.0  -649.0      -649.0    -552.0  -409.0     -409.0
# 2020/12(E)\n(IFRS연결)  1581.0  -434.0         0.0    -331.0  -465.0     -314.0
# 2021/03(E)\n(IFRS연결)  1473.0  -187.0         0.0       0.0     0.0      -33.0
# 2021/06(E)\n(IFRS연결)  1746.0   -65.0         0.0       0.0     0.0      135.0
#
# 주요재무정보                당기순이익(비지배)     자산총계    부채총계     자본총계  ...  ROA(%)  \
# 2019/09\n(IFRS연결)            0.0  41698.0  4781.0  36917.0  ...    7.20
# 2019/12\n(IFRS연결)            0.0  44381.0  7204.0  37178.0  ...    7.72
# 2020/03\n(IFRS연결)            0.0  43702.0  9945.0  33757.0  ...    1.75
# 2020/06\n(IFRS연결)            0.0  39178.0  5900.0  33277.0  ...   -0.50
# 2020/09\n(IFRS연결)            0.0  37434.0  4560.0  32875.0  ...   -4.80
# 2020/12(E)\n(IFRS연결)         0.0  38271.0  5998.0  32274.0  ...    0.00
# 2021/03(E)\n(IFRS연결)         0.0      0.0     0.0      0.0  ...    0.00
# 2021/06(E)\n(IFRS연결)         0.0      0.0     0.0      0.0  ...    0.00
#
# 주요재무정보                 부채비율    자본유보율  EPS(원)  PER(배)   BPS(원)  PBR(배)  \
# 2019/09\n(IFRS연결)     12.95  3513.86   601.0   21.00  18209.0    1.62
# 2019/12\n(IFRS연결)     19.38  3538.24   246.0   18.92  18337.0    1.61
# 2020/03\n(IFRS연결)     29.46  3218.48  -730.0   55.53  16650.0    1.19
# 2020/06\n(IFRS연결)     17.73  3173.64  -213.0    0.00  16414.0    1.31
# 2020/09\n(IFRS연결)     13.87  3136.00  -191.0    0.00  16215.0    1.33
# 2020/12(E)\n(IFRS연결)  18.58     0.00  -147.0    0.00  15888.0    1.46
# 2021/03(E)\n(IFRS연결)   0.00     0.00   -15.0    0.00      0.0    0.00
# 2021/06(E)\n(IFRS연결)   0.00     0.00    63.0    0.00      0.0    0.00
#
# 주요재무정보                현금DPS(원)  현금배당수익률  현금배당성향(%)
# 2019/09\n(IFRS연결)          0.0        0       0.00
# 2019/12\n(IFRS연결)        900.0        0     346.75
# 2020/03\n(IFRS연결)          0.0        0       0.00
# 2020/06\n(IFRS연결)          0.0        0       0.00
# 2020/09\n(IFRS연결)          0.0        0       0.00
# 2020/12(E)\n(IFRS연결)       0.0        0       0.00
# 2021/03(E)\n(IFRS연결)       0.0        0       0.00
# 2021/06(E)\n(IFRS연결)       0.0        0       0.00
#
# [8 rows x 32 columns]

# %%
df1.to_csv("df1.csv")
df2.to_csv("df2.csv")

# %%
df1
# Out:
# 주요재무정보                    매출액   영업이익 영업이익(발표기준) 세전계속사업이익  당기순이익 당기순이익(지배)  \
# 2019/09\n(IFRS연결)     14753.0  574.0      574.0    376.0  274.0     277.0
# 2019/12\n(IFRS연결)     15440.0  776.0      776.0    538.0  380.0     380.0
# 2020/03\n(IFRS연결)      9437.0 -668.0     -668.0   -925.0 -736.0    -736.0
# 2020/06\n(IFRS연결)      5230.0 -634.0     -634.0   -819.0 -677.0    -678.0
# 2020/09\n(IFRS연결)      8795.0 -198.0     -198.0   -366.0 -285.0    -285.0
# 2020/12(E)\n(IFRS연결)   9980.0   50.0        NaN   -109.0 -100.0    -100.0
# 2021/03(E)\n(IFRS연결)   9761.0  144.0        NaN     14.0   71.0      53.0
# 2021/06(E)\n(IFRS연결)   9820.0  265.0        NaN    172.0  214.0     123.0
#
# 주요재무정보               당기순이익(비지배)     자산총계     부채총계    자본총계  ... ROA(%)    부채비율  \
# 2019/09\n(IFRS연결)          -3.0  37747.0  28854.0  8893.0  ...   3.62  324.45
# 2019/12\n(IFRS연결)           0.0  35273.0  26077.0  9195.0  ...   5.81  283.59
# 2020/03\n(IFRS연결)           0.0  33188.0  24813.0  8375.0  ...   1.25  296.28
# 2020/06\n(IFRS연결)           1.0  33039.0  25364.0  7676.0  ...  -2.14  330.45
# 2020/09\n(IFRS연결)           0.0  32683.0  25318.0  7365.0  ...  -3.74  343.77
# 2020/12(E)\n(IFRS연결)        NaN  32388.0  25171.0  7216.0  ...    NaN  348.79
# 2021/03(E)\n(IFRS연결)        NaN      NaN      NaN     NaN  ...    NaN     NaN
# 2021/06(E)\n(IFRS연결)        NaN      NaN      NaN     NaN  ...    NaN     NaN
#
# 주요재무정보                 자본유보율  EPS(원) PER(배)   BPS(원) PBR(배) 현금DPS(원) 현금배당수익률  \
# 2019/09\n(IFRS연결)      395.1   692.0  31.19  23484.0   3.67      0.0     NaN
# 2019/12\n(IFRS연결)     411.78   950.0   21.4  24282.0   3.74    350.0     NaN
# 2020/03\n(IFRS연결)     368.36 -1839.0  63.76  22114.0   3.19      NaN     NaN
# 2020/06\n(IFRS연결)     334.46 -1695.0    NaN  20265.0    3.5      NaN     NaN
# 2020/09\n(IFRS연결)     320.21  -712.0    NaN  19444.0   3.91      NaN     NaN
# 2020/12(E)\n(IFRS연결)     NaN  -251.0    NaN  19187.0   4.22      NaN     NaN
# 2021/03(E)\n(IFRS연결)     NaN   133.0    NaN      NaN    NaN      NaN     NaN
# 2021/06(E)\n(IFRS연결)     NaN   308.0    NaN      NaN    NaN      NaN     NaN
#
# 주요재무정보               현금배당성향(%)
# 2019/09\n(IFRS연결)          0.0
# 2019/12\n(IFRS연결)        34.94
# 2020/03\n(IFRS연결)          0.0
# 2020/06\n(IFRS연결)          0.0
# 2020/09\n(IFRS연결)          NaN
# 2020/12(E)\n(IFRS연결)       NaN
# 2021/03(E)\n(IFRS연결)       NaN
# 2021/06(E)\n(IFRS연결)       NaN
#
# [8 rows x 32 columns]

# %%
df2
# Out:
# 주요재무정보                   매출액    영업이익 영업이익(발표기준) 세전계속사업이익   당기순이익 당기순이익(지배)  \
# 2019/09\n(IFRS연결)     4055.0  1392.0     1392.0   1554.0  1286.0    1286.0
# 2019/12\n(IFRS연결)     3728.0   641.0      641.0    769.0   526.0     526.0
# 2020/03\n(IFRS연결)     2360.0 -1868.0    -1868.0  -2204.0 -1561.0   -1561.0
# 2020/06\n(IFRS연결)      346.0 -1038.0    -1038.0   -723.0  -456.0    -456.0
# 2020/09\n(IFRS연결)      766.0  -649.0     -649.0   -552.0  -409.0    -409.0
# 2020/12(E)\n(IFRS연결)  1581.0  -434.0        NaN   -331.0  -465.0    -314.0
# 2021/03(E)\n(IFRS연결)  1473.0  -187.0        NaN      NaN     NaN     -33.0
# 2021/06(E)\n(IFRS연결)  1746.0   -65.0        NaN      NaN     NaN     135.0
#
# 주요재무정보               당기순이익(비지배)     자산총계    부채총계     자본총계  ... ROA(%)   부채비율  \
# 2019/09\n(IFRS연결)           0.0  41698.0  4781.0  36917.0  ...    7.2  12.95
# 2019/12\n(IFRS연결)           0.0  44381.0  7204.0  37178.0  ...   7.72  19.38
# 2020/03\n(IFRS연결)           0.0  43702.0  9945.0  33757.0  ...   1.75  29.46
# 2020/06\n(IFRS연결)           0.0  39178.0  5900.0  33277.0  ...   -0.5  17.73
# 2020/09\n(IFRS연결)           0.0  37434.0  4560.0  32875.0  ...   -4.8  13.87
# 2020/12(E)\n(IFRS연결)        NaN  38271.0  5998.0  32274.0  ...    NaN  18.58
# 2021/03(E)\n(IFRS연결)        NaN      NaN     NaN      NaN  ...    NaN    NaN
# 2021/06(E)\n(IFRS연결)        NaN      NaN     NaN      NaN  ...    NaN    NaN
#
# 주요재무정보                  자본유보율 EPS(원) PER(배)   BPS(원) PBR(배) 현금DPS(원) 현금배당수익률  \
# 2019/09\n(IFRS연결)     3513.86  601.0   21.0  18209.0   1.62      0.0     NaN
# 2019/12\n(IFRS연결)     3538.24  246.0  18.92  18337.0   1.61    900.0     NaN
# 2020/03\n(IFRS연결)     3218.48 -730.0  55.53  16650.0   1.19      NaN     NaN
# 2020/06\n(IFRS연결)     3173.64 -213.0    NaN  16414.0   1.31      NaN     NaN
# 2020/09\n(IFRS연결)      3136.0 -191.0    NaN  16215.0   1.33      NaN     NaN
# 2020/12(E)\n(IFRS연결)      NaN -147.0    NaN  15888.0   1.46      NaN     NaN
# 2021/03(E)\n(IFRS연결)      NaN  -15.0    NaN      NaN    NaN      NaN     NaN
# 2021/06(E)\n(IFRS연결)      NaN   63.0    NaN      NaN    NaN      NaN     NaN
#
# 주요재무정보               현금배당성향(%)
# 2019/09\n(IFRS연결)          0.0
# 2019/12\n(IFRS연결)       346.75
# 2020/03\n(IFRS연결)          NaN
# 2020/06\n(IFRS연결)          0.0
# 2020/09\n(IFRS연결)          NaN
# 2020/12(E)\n(IFRS연결)       NaN
# 2021/03(E)\n(IFRS연결)       NaN
# 2021/06(E)\n(IFRS연결)       NaN
#
# [8 rows x 32 columns]

# %% [markdown]
# # 2. Feature Engineering
# - 아래 데이터를 참조하여 18/19년도에 대해서 Price to Dream Ratio(PDR)를 계산하세요.
#
#  ## $\rm PDR = {시가총액 \over 해당~기업이~포함된~전체~시장~규모(TAM)~\times~시장점유율}$
#   - 변수 이름 `df3`로 데이터프레임을 생성합니다. 아래와 같은 형태이어야 합니다.
#   - feature 이름은 `PDR`로, `df3['PDR']`을 통해 `~` 값이 확인되어야 합니다.
#     - PDR에 100을 곱한 백분율(%)을 구합니다.
#
# ||구분|종가|발행주식수|시가총액|시장점유율|시장규모|PDR|
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# |0|18년|101500|137292497|13935188445500|62.0|15000000000000|~|
# |1|19년|93800|137292497|12878036218600|63.5|15000000000000|~|

# %%
import pandas as pd
import numpy as np

# %%
df3 = pd.DataFrame({'구분':['18년','19년'],
                    '종가':[101500,93800],
                    '발행주식수':[137292497,137292497],
                    '시가총액':[13935188445500,12878036218600],
                    '시장점유율':[62.0,63.5],
                    '시장규모':[15000000000000,15000000000000],
                    'PDR':['~','~']
                  })
df3
# Out:
#     구분      종가      발행주식수            시가총액  시장점유율            시장규모 PDR
# 0  18년  101500  137292497  13935188445500   62.0  15000000000000   ~
# 1  19년   93800  137292497  12878036218600   63.5  15000000000000   ~

# %%
df3['PDR'] = (df3['시가총액']/(df3['시장규모']*(df3['시장점유율']/100)))*100
df3
# Out:
#     구분      종가      발행주식수            시가총액  시장점유율            시장규모         PDR
# 0  18년  101500  137292497  13935188445500   62.0  15000000000000  149.840736
# 1  19년   93800  137292497  12878036218600   63.5  15000000000000  135.202480

# %% [markdown]
# # 3. 중복된 데이터 살펴보기
#
# - 와인 데이터셋을 사용합니다.
#
# - 공식문서를 참조하여 중복된 데이터를 모두 확인해 봅니다. <br>
#   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4998336-efd9-43ee-a178-6335ec8a0212" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4998336-efd9-43ee-a178-6335ec8a0212">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red (2).csv
# Saving winequality-white.csv to winequality-white (1).csv

# %%
df_red = pd.read_csv('winequality-red.csv')
df_red.head()
# Out:
#   fixed_acidity;volatile_acidity;citric_acid;residual_sugar;chlorides;free_sulfur_dioxide;total_sulfur-dioxide;density;pH;sulphates;alcohol;quality
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
df_red = pd.read_csv('winequality-red.csv', sep=';')
df_red.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df_white = pd.read_csv('winequality-white.csv', sep=';')
df_white.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur-dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4898 non-null   float64
#  1   volatile_acidity      4898 non-null   float64
#  2   citric_acid           4898 non-null   float64
#  3   residual_sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free_sulfur_dioxide   4898 non-null   float64
#  6   total_sulfur_dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_red.duplicated(['fixed_acidity'], keep='first') #  keep = 'first' 첫 번째값은 False, 두 번째 값부터는 True 반환
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1594     True
# 1595     True
# 1596     True
# 1597     True
# 1598     True
# Length: 1599, dtype: bool

# %%
df_red.duplicated(['fixed_acidity'])  #  keep='first'와 같음
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1354     True
# 1355     True
# 1356     True
# 1357     True
# 1358     True
# Length: 1359, dtype: bool

# %%
df_red.duplicated(['fixed_acidity'],keep='last') # keep = 'last'  first의 반대
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595     True
# 1596    False
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
df_red.duplicated(['fixed_acidity'], keep=False) # keep = False  처음과 끝과 관계없이 중복이면 True
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1594    True
# 1595    True
# 1596    True
# 1597    True
# 1598    True
# Length: 1599, dtype: bool

# %%
df_red.nunique()
# Out:
# fixed_acidity            96
# volatile_acidity        143
# citric_acid              80
# residual_sugar           91
# chlorides               153
# free_sulfur_dioxide      60
# total_sulfur-dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
df_red.duplicated().sum()
# Out:
# 240

# %%
df_red = df_red.drop_duplicates()  # 중복제거
df_red.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 5      9.4        5

# %%
df_red = df_red.reset_index(drop=True)  # index 정렬
df_red.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df_red.shape
# Out:
# (1359, 12)

# %%
df_white.shape
# Out:
# (4898, 12)

# %%
df_white.duplicated(['fixed_acidity'], keep='first')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4893     True
# 4894     True
# 4895     True
# 4896     True
# 4897     True
# Length: 4898, dtype: bool

# %%
df_white.duplicated(['fixed_acidity'], keep='last')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# Length: 4898, dtype: bool

# %%
df_white.duplicated(['fixed_acidity'], keep=False)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4893    True
# 4894    True
# 4895    True
# 4896    True
# 4897    True
# Length: 4898, dtype: bool

# %%
df_white.duplicated().sum()
# Out:
# 937

# %%
df_white = df_white.drop_duplicates()
df_white.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 6      9.6        6

# %%
df_white = df_white.reset_index(drop=True)
df_white.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            6.2              0.32         0.16             7.0      0.045
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.6        6

# %%
df_white.shape
# Out:
# (3961, 12)

# %% [markdown]
# # 🔥 도전과제

# %% [markdown]
# ## NA Value Handling
#
# - 데이터셋을 불러옵니다.
#
# - 19년도 4분기의 당기순이익(비지배) 부분을 Na로 대체하세요
#
# - 이후 해당 결측치를 mean imputation 방법을 사용하여 처리하세요.

# %%
url = 'https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/kt%26g/kt%26g_0.csv'
headers = ['분기', '매출액', '영업이익', '영업이익(발표기준)', '세전계속사업이익',
           '당기순이익', '당기순이익(지배)', '당기순이익(비지배)', '자산총계', '부채총계',
           '자본총계', '자본총계(지배)', '자본총계(비지배)', '자본금', '영업활동현금흐름',
           '투자활동현금흐름', '재무활동현금흐름', '영업이익률', '순이익률', 'ROE(%)',
           'ROA(%)', '부채비율', '자본유보율', 'EPS(원)', 'PER(배)']

# %%
# 이 곳에 답안을 작성하시기 바랍니다.

# %% [markdown]
# ## Feature Engineering
#
# Relative Perfomance 라는 새로운 feature를 계산하세요.
#
# 이는 최근 1년치 매출액의 평균값을 기준으로
#
# - 10% 이상 -> `S`
# - 5% 이상 -> `A`
# - -5 ~ 5% -> `B`
# - -5%이하 -> `C`
# - 10%이하 -> `D`
#
# 라는 값을 갖는 feature입니다.
#
# 20년도 2분기에 해당하는 결과값은 `A`가 나와야합니다.
#
# 각각에 해당하는 등급이 나오기 위해서 필요한 매출액을 추가로 서술하세요.

# %%
# 이 곳에 답안을 작성하시기 바랍니다.
